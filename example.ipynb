# %% [markdown]
# # CarbonTracker MVP Example
# This notebook demonstrates the legacy manual tracking API using the new decoupled Observer architecture.

# %%
import time
from carbontracker.entrypoints.programmatic.manual import CarbonTracker

# 1. Initialize the CarbonTracker with legacy defaults
# This automatically creates a ManualObserver and necessary DummyProviders
tats


# 2. Run a training loop using the manual epoch boundaries
for epoch in range(2):
    print(f"\n--- Starting Epoch {epoch} ---")
    tracker.epoch_start()
    
    # Simulate some heavy compute
    time.sleep(2.5)
    
    tracker.epoch_end()
    print(f"--- Finished Epoch {epoch} ---")

# 3. Gracefully stop all tracking threads and generate the report
tracker.stop()
print("\nTracking complete!")
# Out:
# --- Starting Epoch 0 ---
# [WriterThread] Processing Event: EventStart(started_at=datetime.datetime(2026, 5, 24, 20, 18, 42, 342802), span_id='epoch_1')
# [WriterThread] Processing Event: MeasurementEvent(provider_name='power', timestamp=datetime.datetime(2026, 5, 24, 20, 18, 42, 34
# 2516), data=PowerMeasurementData(timestamp=datetime.datetime(2026, 5, 24, 20, 18, 42, 342516), source_id='CPU:0', wattage=10.0,
# source='intel-rapl', device_id='CPU:0', pid=0))
# [WriterThread] Processing Event: MeasurementEvent(provider_name='power', timestamp=datetime.datetime(2026, 5, 24, 20, 18, 42, 34
# 2530), data=PowerMeasurementData(timestamp=datetime.datetime(2026, 5, 24, 20, 18, 42, 342530), source_id='GPU:0', wattage=50.0,
# source='nvidia-smi', device_id='GPU:0', pid=0))
# [WriterThread] Processing Event: MeasurementEvent(provider_name='power', timestamp=datetime.datetime(2026, 5, 24, 20, 18, 42, 34
# ...
